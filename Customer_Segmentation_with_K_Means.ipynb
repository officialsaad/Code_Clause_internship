# %% [markdown]
# #  **Customer Segmentation with K-Means Clustering**
#
# #### *Notebook Author Name :* Saad Ahmad

# %% [markdown]
# ## *Aim*
# 1. Apply K-Means clustering to segment customers based on their purchase behavior

# %% [markdown]
# ## *Data Collection*
# 1. *Dataset Link*: https://www.kaggle.com/datasets/zubairmustafa/shopping-mall-customer-segmentation-data/code

# %%
#importing liraries
import numpy as np # for making Numpy array

import pandas as pd # for making data frame

import matplotlib.pyplot as plt # for plotting graphs

# %% [markdown]
# ## *About Dataset*

# %%
# load the csv file
df = pd.read_csv('./dataset/Shopping Mall Customer Segmentation Data .csv')

# %%
# display dataframe
df.head(-5)
# Out:
#                                 Customer ID  Age  Gender  Annual Income  \
# 0      d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1      1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2      e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3      9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4      64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
# ...                                     ...  ...     ...            ...
# 15069  5ba45b3d-8dfa-4b93-8f81-5e0a40aff47e   55    Male          71393
# 15070  50fbfed1-7d60-4398-bf45-3f246bb6369f   45  Female          68342
# 15071  720d5085-0248-4939-b8c1-9261b5896cb5   40  Female          27768
# 15072  02da8108-fe4f-4300-a4d3-e2210f8d240f   35  Female         105107
# 15073  21c26582-4425-4296-8305-4045edba61b8   70  Female         108936
#
#        Spending Score
# 0                  89
# 1                  95
# 2                  76
# ...

# %%
# getting the shape of dataframe
df.shape
# Out:
# (15079, 5)

# %%
# finding the info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15079 entries, 0 to 15078
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     15079 non-null  object
#  1   Age             15079 non-null  int64
#  2   Gender          15079 non-null  object
#  3   Annual Income   15079 non-null  int64
#  4   Spending Score  15079 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 589.1+ KB

# %%
# Finding the Null or missing value
df.isnull().sum()
# Out:
# Customer ID       0
# Age               0
# Gender            0
# Annual Income     0
# Spending Score    0
# dtype: int64

# %%
#finding the column names
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Annual Income', 'Spending Score'], dtype='object')

# %% [markdown]
# ## Choosing *'Annual Income'* and *'Spending Score'* Column in dataframe

# %%
# so we don't have missing value get column values
x = df.iloc[:,[3,4]].values
print(x)
# Out:
# [[151479     89]
#  [185088     95]
#  [ 70912     76]
#  ...
#  [112337     48]
#  [ 94312      5]
#  [ 78045      2]]

# %% [markdown]
# ## Choosing the Number of Clusters

# %%
from sklearn.cluster import KMeans

# %%
# finding the optimum number of cluster by parameter
# WCSS -> with in the cluster sum of squares value

list = []
for i in range(1,11):
  kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
  kmeans.fit(x)
  list.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Ploting the graph to know which has minimum value
import seaborn as sns

# %%
sns.set()
plt.plot(range(1,11),list)
plt.title('CutOFF point Graph')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# so optimun number of cluster 3 interpreted from graph

# %% [markdown]
# ## Training the k-Means Clustering Model

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)

# return the label
labels = kmeans.fit_predict(x)
print(labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 1 2 ... 0 0 2]

# %% [markdown]
# ## *Visuallizing all the Cluster*

# %%
# plotting centroids and all cluster
plt.figure(figsize=(10,10))
plt.scatter(x[labels==0,0], x[labels==0,1], s=30, c='grey', label ='cluster 1')
plt.scatter(x[labels==1,0], x[labels==1,1], s=30, c='green', label ='cluster 2')
plt.scatter(x[labels==2,0], x[labels==2,1], s=30, c='blue', label ='cluster 3')

# all in x[labels == #,0] 0 repesent the annual income which is first column in x
# all 1 in x[labels == #,1] 1 represent the sprending score which is second column i x

# Ploting Centroids
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], s=60, c='cyan', label='Centroids')
plt.title('Customer Groups')
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()
